# %% [markdown]
# <a href="https://colab.research.google.com/github/akashprakash08/fakecurrrencydetect/blob/main/50rs_new_secondlast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 pip install opencv-python

# %%
pip install numpy

# %%
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt

# Upload an image from the user
uploaded = files.upload()


# Display the uploaded image
for fn in uploaded.keys():
    img_path = fn
    img = Image.open(fn)
    plt.imshow(img)
    plt.axis('off')
    plt.show()
# Out:
#      <input type="file" id="files-ff39a739-a3cc-480a-aa69-3e2cedab9d3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff39a739-a3cc-480a-aa69-3e2cedab9d3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from PIL import Image

# Load the image
uploaded_image_path = list(uploaded.keys())[0]
img = cv2.imread(uploaded_image_path)

# Convert the image to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Display the grayscale image
Image.fromarray(gray_img)

# Get the height and width of the grayscale image
height, width = gray_img.shape

# Show the height and width of the image
print(f'Height: {height}, Width: {width}')
# Out:
# Height: 1099, Width: 2247

# %%
height = 766
width = 1578

# %%
import cv2
img2_resized = cv2.resize(gray_img, (width, height))

# Get the dimensions of the resized image
height2_resized, width2_resized, = img2_resized.shape


# Show the height and width of the resized image
print(f'Height: {height2_resized}, Width: {width2_resized}')
# Out:
# Height: 766, Width: 1578

# %%
from google.colab.patches import cv2_imshow


rdn = img2_resized[540:620, 100:200]
cv2_imshow(rdn)
# Out:
# <PIL.Image.Image image mode=L size=100x80>

# %%
import os
def check_similarity(img1, img2, threshold_matches=15, threshold_distance=0.6):
    # Initialize SIFT
    sift = cv2.SIFT_create()

    # Find keypoints and descriptors
    kp11, des11 = sift.detectAndCompute(rdnOR, None)
    kp12, des12 = sift.detectAndCompute(rdn, None)

    # Create BFMatcher object
    bf = cv2.BFMatcher()

    # Match descriptors
    matches = bf.knnMatch(des11, des12, k=2)

    # Apply ratio test
    good_matches = []
    for m, n in matches:
        if m.distance < threshold_distance * n.distance:
            good_matches.append(m)

    # Check if number of good matches exceeds threshold
    if len(good_matches) >= threshold_matches:
        return True, len(good_matches), kp11, kp12, good_matches
    else:
        return False, len(good_matches), kp11, kp12, good_matches

# Load the images
rdn = rdnOR

# Path to the feature 5 dataset
dataset_path = '/content/drive/MyDrive/testing dataset/dataset/50 features/50 features/feacture 1'

# Initialize ORB
orb = cv2.ORB_create()

# Iterate through the dataset
similar_count = 0
for file_name in os.listdir(dataset_path):
    rdn_path = os.path.join(dataset_path, file_name)
    Rdn = cv2.imread(rdn_path, cv2.IMREAD_GRAYSCALE)

    # Check similarity
    is_similar, num_matches, kp11, kp12, good_matches = check_similarity(rdn, Rdn, threshold_matches=10, threshold_distance=0.6)

    if is_similar:
        print(f"The regions in {file_name} are similar with {num_matches} good matches.")
        similar_count += 1

    else:
        print(f"The regions in {file_name} are not similar with {num_matches} good matches.")

    # Visualize keypoints and matches
if similar_count >= len(os.listdir(dataset_path)) // 2:
    print("Region is original.")
else:
    print("Region is Fake.")
# Out:
# The regions in 1.jpg are similar with 26 good matches.
# The regions in 2.jpg are similar with 26 good matches.
# The regions in 3.jpg are similar with 26 good matches.
# The regions in 4.jpg are similar with 26 good matches.
# Region is original.

# %%
ndevanagari = img2_resized[300:550, 250:380]
cv2_imshow(ndevanagari)
# Out:
# <PIL.Image.Image image mode=L size=130x250>

# %%
import os
def check_similarity(img1, img2, threshold_matches=15, threshold_distance=0.6):
    # Initialize SIFT
    sift = cv2.SIFT_create()

    # Find keypoints and descriptors
    kp11, des11 = sift.detectAndCompute(img1, None)
    kp12, des12 = sift.detectAndCompute(img2, None)

    # Create BFMatcher object
    bf = cv2.BFMatcher()

    # Match descriptors
    matches = bf.knnMatch(des11, des12, k=2)

    # Apply ratio test
    good_matches = []
    for m, n in matches:
        if m.distance < threshold_distance * n.distance:
            good_matches.append(m)

    # Check if number of good matches exceeds threshold
    if len(good_matches) >= threshold_matches:
        return True, len(good_matches), kp11, kp12, good_matches
    else:
        return False, len(good_matches), kp11, kp12, good_matches

# Load the images
Ndevanagari = ndevanagari

# Path to the feature 5 dataset
dataset_path = '/content/drive/MyDrive/testing dataset/dataset/50 features/50 features/feature 2'

# Initialize ORB
orb = cv2.ORB_create()

# Iterate through the dataset
similar_count = 0
for file_name in os.listdir(dataset_path):
    ndevanagari_path = os.path.join(dataset_path, file_name)
    Fgc1 = cv2.imread(ndevanagari_path, cv2.IMREAD_GRAYSCALE)

    # Check similarity
    is_similar, num_matches, kp11, kp12, good_matches = check_similarity(Ndevanagari, Fgc1, threshold_matches=10, threshold_distance=0.6)

    if is_similar:
        print(f"The regions in {file_name} are similar with {num_matches} good matches.")
        similar_count += 1

    else:
        print(f"The regions in {file_name} are not similar with {num_matches} good matches.")

    # Visualize keypoints and matches
if similar_count >= len(os.listdir(dataset_path)) // 2:
    print("Region is original.")
else:
    print("Region is Fake.")
# Out:
# The regions in f2_01.jpg are similar with 32 good matches.
# The regions in f2_02.jpg are similar with 32 good matches.
# The regions in f2_03.jpg are similar with 33 good matches.
# The regions in f2_04.jpg are similar with 33 good matches.
# The regions in f2_05.jpg are similar with 29 good matches.
# Region is original.

# %%
gandhi = img2_resized[200:730, 280:890]
cv2_imshow(gandhi)
# Out:
# <PIL.Image.Image image mode=L size=610x530>

# %%
def check_similarity(img1, img2, threshold_matches=15, threshold_distance=0.6):
    # Initialize SIFT
    sift = cv2.SIFT_create()

    # Find keypoints and descriptors
    kp11, des11 = sift.detectAndCompute(img1, None)
    kp12, des12 = sift.detectAndCompute(img2, None)

    # Create BFMatcher object
    bf = cv2.BFMatcher()

    # Match descriptors
    matches = bf.knnMatch(des11, des12, k=2)

    # Apply ratio test
    good_matches = []
    for m, n in matches:
        if m.distance < threshold_distance * n.distance:
            good_matches.append(m)

    # Check if number of good matches exceeds threshold
    if len(good_matches) >= threshold_matches:
        return True, len(good_matches), kp11, kp12, good_matches
    else:
        return False, len(good_matches), kp11, kp12, good_matches

# Load the images
Gandhi = gandhi

# Path to the feature 5 dataset
dataset_path = '/content/drive/MyDrive/testing dataset/dataset/50 features/50 features/feature 3'

# Initialize ORB
orb = cv2.ORB_create()

# Iterate through the dataset
similar_count = 0
for file_name in os.listdir(dataset_path):
    gandhi_path = os.path.join(dataset_path, file_name)
    gandhi = cv2.imread(gandhi_path, cv2.IMREAD_GRAYSCALE)

    # Check similarity
    is_similar, num_matches, kp11, kp12, good_matches = check_similarity(Gandhi, gandhi, threshold_matches=10, threshold_distance=0.6)

    if is_similar:
        print(f"The regions in {file_name} are similar with {num_matches} good matches.")
        similar_count += 1

    else:
        print(f"The regions in {file_name} are not similar with {num_matches} good matches.")

    # Visualize keypoints and matches
if similar_count >= len(os.listdir(dataset_path)) // 2:
    print("Region is original.")
else:
    print("Region is Fake.")
# Out:
# The regions in f3_01.jpg are similar with 1197 good matches.
# The regions in f3_03.jpg are similar with 1206 good matches.
# The regions in f3_02.jpg are similar with 1246 good matches.
# The regions in f3_04.jpg are similar with 885 good matches.
# The regions in f3_05.jpg are similar with 1993 good matches.
# Region is original.

# %%
guarantee_clause = img2_resized[130:500, 880:1080]
cv2_imshow(guarantee_clause)
# Out:
# <PIL.Image.Image image mode=L size=200x370>

# %%
def check_similarity(img1, img2, threshold_matches=15, threshold_distance=0.6):
    # Initialize SIFT
    sift = cv2.SIFT_create()

    # Find keypoints and descriptors
    kp11, des11 = sift.detectAndCompute(img1, None)
    kp12, des12 = sift.detectAndCompute(img2, None)

    # Create BFMatcher object
    bf = cv2.BFMatcher()

    # Match descriptors
    matches = bf.knnMatch(des11, des12, k=2)

    # Apply ratio test
    good_matches = []
    for m, n in matches:
        if m.distance < threshold_distance * n.distance:
            good_matches.append(m)

    # Check if number of good matches exceeds threshold
    if len(good_matches) >= threshold_matches:
        return True, len(good_matches), kp11, kp12, good_matches
    else:
        return False, len(good_matches), kp11, kp12, good_matches

# Load the images
Guarantee_clause = guarantee_clause

# Path to the feature 5 dataset
dataset_path = '/content/drive/MyDrive/testing dataset/dataset/50 features/50 features/feature 4'

# Initialize ORB
orb = cv2.ORB_create()

# Iterate through the dataset
similar_count = 0
for file_name in os.listdir(dataset_path):
    guarantee_clause_path = os.path.join(dataset_path, file_name)
    guarantee_clause = cv2.imread(guarantee_clause_path, cv2.IMREAD_GRAYSCALE)

    # Check similarity
    is_similar, num_matches, kp11, kp12, good_matches = check_similarity(Guarantee_clause, guarantee_clause, threshold_matches=10, threshold_distance=0.6)

    if is_similar:
        print(f"The regions in {file_name} are similar with {num_matches} good matches.")
        similar_count += 1

    else:
        print(f"The regions in {file_name} are not similar with {num_matches} good matches.")

    # Visualize keypoints and matches
if similar_count >= len(os.listdir(dataset_path)) // 2:
    print("Region is original.")
else:
    print("Region is Fake.")
# Out:
# The regions in f4_01.jpg are similar with 723 good matches.
# The regions in f4_02.jpg are similar with 745 good matches.
# The regions in f4_03.jpg are similar with 744 good matches.
# The regions in f4_04.jpg are similar with 480 good matches.
# The regions in f4_05.jpg are similar with 1069 good matches.
# Region is original.

# %%
hindigurantee = img2_resized[115:160, 160:500]
cv2_imshow(hindigurantee)
# Out:
# <PIL.Image.Image image mode=L size=340x45>

# %%
def check_similarity(gc2, Fgc2, threshold_matches=15, threshold_distance=0.6):
    # Initialize SIFT
    sift = cv2.SIFT_create()

    # Find keypoints and descriptors
    kp11, des11 = sift.detectAndCompute(gc2, None)
    kp12, des12 = sift.detectAndCompute(Fgc2, None)

    # Create BFMatcher object
    bf = cv2.BFMatcher()

    # Match descriptors
    matches = bf.knnMatch(des11, des12, k=2)

    # Apply ratio test
    good_matches = []
    for m, n in matches:
        if m.distance < threshold_distance * n.distance:
            good_matches.append(m)

    # Check if number of good matches exceeds threshold
    if len(good_matches) >= threshold_matches:
        return True, len(good_matches), kp11, kp12, good_matches
    else:
        return False, len(good_matches), kp11, kp12, good_matches

# Load the images
gc1 = img2_resized[115:160, 160:500]

# Path to the feature 5 dataset
dataset_path = '/content/drive/MyDrive/testing dataset/dataset/50 features/50 features/feature 5'

# Initialize ORB
orb = cv2.ORB_create()

# Iterate through the dataset
similar_count = 0
for file_name in os.listdir(dataset_path):
    Fgc1_path = os.path.join(dataset_path, file_name)
    Fgc1 = cv2.imread(Fgc1_path, cv2.IMREAD_GRAYSCALE)

    # Check similarity
    is_similar, num_matches, kp11, kp12, good_matches = check_similarity(gc1, Fgc1, threshold_matches=10, threshold_distance=0.6)

    if is_similar:
        print(f"The regions in {file_name} are similar with {num_matches} good matches.")
        similar_count += 1

    else:
        print(f"The regions in {file_name} are not similar with {num_matches} good matches.")

    # Visualize keypoints and matches
if similar_count >= len(os.listdir(dataset_path)) // 2:
    print("Region is original.")
else:
    print("Region is not original.")
# Out:
# The regions in f5_01.jpg are similar with 30 good matches.
# The regions in f5_02.jpg are similar with 26 good matches.
# The regions in f5_03.jpg are similar with 26 good matches.
# The regions in f5_04.jpg are similar with 26 good matches.
# The regions in f5_05.jpg are similar with 24 good matches.
# Region is original.

# %%
ashokapillar = img2_resized[420:620, 1400:1550]
cv2_imshow(ashokapillar)
# Out:
# <PIL.Image.Image image mode=L size=150x200>

# %%
import os
def check_similarity(img1, img2, threshold_matches=15, threshold_distance=0.6):
    # Initialize SIFT
    sift = cv2.SIFT_create()

    # Find keypoints and descriptors
    kp11, des11 = sift.detectAndCompute(ashokapillar, None)
    kp12, des12 = sift.detectAndCompute(Fashokapillar, None)

    # Create BFMatcher object
    bf = cv2.BFMatcher()

    # Match descriptors
    matches = bf.knnMatch(des11, des12, k=2)

    # Apply ratio test
    good_matches = []
    for m, n in matches:
        if m.distance < threshold_distance * n.distance:
            good_matches.append(m)

    # Check if number of good matches exceeds threshold
    if len(good_matches) >= threshold_matches:
        return True, len(good_matches), kp11, kp12, good_matches
    else:
        return False, len(good_matches), kp11, kp12, good_matches

# Load the images
Fashokapillar = ashokapillar

# Path to the feature 5 dataset
dataset_path = '/content/drive/MyDrive/testing dataset/dataset/50 features/50 features/feature 7'

# Initialize ORB
orb = cv2.ORB_create()

# Iterate through the dataset
similar_count = 0
for file_name in os.listdir(dataset_path):
    rdn_path = os.path.join(dataset_path, file_name)
    Fashokapillar = cv2.imread(rdn_path, cv2.IMREAD_GRAYSCALE)

    # Check similarity
    is_similar, num_matches, kp11, kp12, good_matches = check_similarity(ashokapillar, Fashokapillar, threshold_matches=10, threshold_distance=0.6)

    if is_similar:
        print(f"The regions in {file_name} are similar with {num_matches} good matches.")
        similar_count += 1

    else:
        print(f"The regions in {file_name} are not similar with {num_matches} good matches.")

    # Visualize keypoints and matches
if similar_count >= len(os.listdir(dataset_path)) // 2:
    print("Region is original.")
else:
    print("Region is Fake.")
# Out:
# The regions in f7_01.jpg are similar with 46 good matches.
# The regions in f7_02.jpg are similar with 46 good matches.
# The regions in f7_03.jpg are similar with 58 good matches.
# The regions in f7_04.jpg are similar with 60 good matches.
# The regions in f7_05.jpg are similar with 40 good matches.
# Region is original.

# %%
gurantee = img2_resized[105:150, 1000:1430]
cv2_imshow(gurantee)
# Out:
# <PIL.Image.Image image mode=L size=430x45>

# %%
import os
def check_similarity(img1, img2, threshold_matches=15, threshold_distance=0.6):
    # Initialize SIFT
    sift = cv2.SIFT_create()

    # Find keypoints and descriptors
    kp11, des11 = sift.detectAndCompute(gurantee, None)
    kp12, des12 = sift.detectAndCompute(Fgurantee, None)

    # Create BFMatcher object
    bf = cv2.BFMatcher()

    # Match descriptors
    matches = bf.knnMatch(des11, des12, k=2)

    # Apply ratio test
    good_matches = []
    for m, n in matches:
        if m.distance < threshold_distance * n.distance:
            good_matches.append(m)

    # Check if number of good matches exceeds threshold
    if len(good_matches) >= threshold_matches:
        return True, len(good_matches), kp11, kp12, good_matches
    else:
        return False, len(good_matches), kp11, kp12, good_matches

# Load the images
Fgurantee = gurantee

# Path to the feature 5 dataset
dataset_path = '/content/drive/MyDrive/testing dataset/dataset/50 features/50 features/feature 6'

# Initialize ORB
orb = cv2.ORB_create()

# Iterate through the dataset
similar_count = 0
for file_name in os.listdir(dataset_path):
    rdn_path = os.path.join(dataset_path, file_name)
    Fgurantee = cv2.imread(rdn_path, cv2.IMREAD_GRAYSCALE)

    # Check similarity
    is_similar, num_matches, kp11, kp12, good_matches = check_similarity(gurantee, Fgurantee, threshold_matches=10, threshold_distance=0.6)

    if is_similar:
        print(f"The regions in {file_name} are similar with {num_matches} good matches.")
        similar_count += 1

    else:
        print(f"The regions in {file_name} are not similar with {num_matches} good matches.")

    # Visualize keypoints and matches
if similar_count >= len(os.listdir(dataset_path)) // 2:
    print("Region is original.")
else:
    print("Region is Fake.")
# Out:
# The regions in f6_01.jpg are similar with 90 good matches.
# The regions in f6_02.jpg are similar with 98 good matches.
# The regions in f6_03.jpg are similar with 92 good matches.
# The regions in f6_04.jpg are similar with 100 good matches.
# The regions in f6_05.jpg are similar with 81 good matches.
# Region is original.

# %%
# !pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 24.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 45.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 25.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 49.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 49.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 79.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 503.4 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.9 MB/s eta 0:00:00
# ...

# %%
import easyocr
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# Load the image
image =  img2_resized[630:730, 950:1420]


# Initialize the EasyOCR reader
reader = easyocr.Reader(['en'])

# Perform OCR on the image
result = reader.readtext(image)

# Display the image with bounding boxes around the detected characters
count = 0
for detection in result:
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    image = cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)
    image = cv2.putText(image, text, top_left, font, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
    count += len(text)

# Display the image
cv2_imshow(image)

# Print the number of characters detected
print("Number of characters:", count)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# <PIL.Image.Image image mode=L size=470x100>
# Number of characters: 9
